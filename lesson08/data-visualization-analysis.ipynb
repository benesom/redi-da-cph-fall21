# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
data = pd.read_csv('gdrive/My Drive/marketing_campaign.csv',sep='\t')
print("Shape: ",data.shape)
print("Length: ",len(data))
print("Size: ",data.size)
data.head(5)
# Out:
# Shape:  (2240, 29)
# Length:  2240
# Size:  64960
#      ID  Year_Birth   Education  ... Z_CostContact  Z_Revenue  Response
# 0  5524        1957  Graduation  ...             3         11         1
# 1  2174        1954  Graduation  ...             3         11         0
# 2  4141        1965  Graduation  ...             3         11         0
# 3  6182        1984  Graduation  ...             3         11         0
# 4  5324        1981         PhD  ...             3         11         0
#
# [5 rows x 29 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
import missingno as mn
mn.matrix(data)

# %%
data=data.dropna()
print("Length: ",len(data))
data.info()
# Out:
# Length:  2216
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2216 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2216 non-null   int64
#  1   Year_Birth           2216 non-null   int64
#  2   Education            2216 non-null   object
#  3   Marital_Status       2216 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2216 non-null   int64
#  6   Teenhome             2216 non-null   int64
#  7   Dt_Customer          2216 non-null   object
#  8   Recency              2216 non-null   int64
#  9   MntWines             2216 non-null   int64
#  10  MntFruits            2216 non-null   int64
#  11  MntMeatProducts      2216 non-null   int64
#  12  MntFishProducts      2216 non-null   int64
#  13  MntSweetProducts     2216 non-null   int64
#  14  MntGoldProds         2216 non-null   int64
# ...

# %%
data.describe()
# Out:
#                  ID   Year_Birth  ...  Z_Revenue     Response
# count   2216.000000  2216.000000  ...     2216.0  2216.000000
# mean    5588.353339  1968.820397  ...       11.0     0.150271
# std     3249.376275    11.985554  ...        0.0     0.357417
# min        0.000000  1893.000000  ...       11.0     0.000000
# 25%     2814.750000  1959.000000  ...       11.0     0.000000
# 50%     5458.500000  1970.000000  ...       11.0     0.000000
# 75%     8421.750000  1977.000000  ...       11.0     0.000000
# max    11191.000000  1996.000000  ...       11.0     1.000000
#
# [8 rows x 26 columns]

# %%
import missingno as mn
print(mn.matrix(data))
# Out:
# AxesSubplot(0.125,0.125;0.698618x0.755)

# %%
data=data.drop(columns=['ID'])
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import colors
corrmat= data.corr()
plt.figure(figsize=(18,10))  
sns.heatmap(corrmat,annot=True, cmap="BuPu", center=0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(26, 6))
sns.countplot(x="Education", data=data)

# %%
plt.figure(figsize=(28, 6))
sns.countplot(x="Year_Birth", data=data)

# %%
plt.figure(figsize=(28, 6))
sns.countplot(x="Marital_Status", data=data)

# %%
#plt.figure(figsize=(28, 6))
#sns.countplot(x="Dt_Customer", data=data)
data["Dt_Customer"].value_counts()
# Out:
# 31-08-2012    12
# 14-02-2013    11
# 12-09-2012    11
# 12-05-2014    11
# 22-05-2014    10
#               ..
# 13-09-2013     1
# 31-07-2012     1
# 06-01-2014     1
# 30-10-2012     1
# 22-04-2014     1
# Name: Dt_Customer, Length: 662, dtype: int64

# %%
sns.countplot(x="Complain", data=data)

# %%
plt.figure(figsize=(28, 6))
sns.countplot(x="Recency", data=data)

# %%
plt.figure(figsize=(28, 6))
sns.countplot(x="Response", data=data)

# %%
plt.figure(figsize=(28, 6))
sns.countplot(x="AcceptedCmp3", data=data)

# %%
plt.figure(figsize=(28, 6))
sns.countplot(x="AcceptedCmp2", data=data)

# %%
plt.figure(figsize=(28, 6))
sns.countplot(x="AcceptedCmp1", data=data)

# %%
plt.figure(figsize=(28, 6))
sns.countplot(x="AcceptedCmp4", data=data)

# %%
plt.figure(figsize=(28, 6))
sns.countplot(x="AcceptedCmp5", data=data)

# %%
data['Marital_Status'] = data['Marital_Status'].replace(['Married', 'Together'],'Relationship')
data['Marital_Status'] = data['Marital_Status'].replace(['Divorced', 'Widow', 'Alone', 'YOLO', 'Absurd'],'Single')

# %%
plt.figure(figsize=(28, 6))
sns.countplot(x="Marital_Status", data=data)

# %%
plt.figure(figsize=(28, 6))
sns.distplot(data["Income"],color = 'Seagreen')

# %%
data['NumTotalPurchases'] = data['NumWebPurchases'] + data['NumCatalogPurchases'] + data['NumStorePurchases'] + data['NumDealsPurchases']

# %%
plt.figure(figsize=(28, 6))
sns.distplot(data["NumTotalPurchases"],color = 'Seagreen')

# %%
data['Expenditure'] = data['MntWines'] + data['MntFruits'] + data['MntMeatProducts'] + data['MntFishProducts'] + data['MntSweetProducts'] + data['MntGoldProds']

# %%
plt.figure(figsize=(28, 6))
sns.distplot(data["Expenditure"],color = 'Seagreen')

# %%
data['TotalAcceptedCmp'] = data['AcceptedCmp1'] + data['AcceptedCmp2'] + data['AcceptedCmp3'] + data['AcceptedCmp4'] + data['AcceptedCmp5']
plt.figure(figsize=(28, 6))
sns.distplot(data["TotalAcceptedCmp"],color = 'Seagreen')

# %%
col_to_del = ["AcceptedCmp1" , "AcceptedCmp2", "AcceptedCmp3" , "AcceptedCmp4","AcceptedCmp5","NumWebVisitsMonth", "NumWebPurchases","NumCatalogPurchases","NumStorePurchases","NumDealsPurchases" , "Kidhome", "Teenhome","MntWines", "MntFruits", "MntMeatProducts", "MntFishProducts", "MntSweetProducts", "MntGoldProds"]
data=data.drop(columns=col_to_del,axis=1)
print(data.columns)
data.head()
# Out:
# Index(['Year_Birth', 'Education', 'Marital_Status', 'Income', 'Dt_Customer',
#        'Recency', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response',
#        'NumTotalPurchases', 'Expenditure', 'TotalAcceptedCmp'],
#       dtype='object')
#    Year_Birth   Education  ... Expenditure  TotalAcceptedCmp
# 0        1957  Graduation  ...        1617                 0
# 1        1954  Graduation  ...          27                 0
# 2        1965  Graduation  ...         776                 0
# 3        1984  Graduation  ...          53                 0
# 4        1981         PhD  ...         422                 0
#
# [5 rows x 13 columns]

# %%
from datetime import date
data['Dt_Customer'] = pd.to_datetime(data.Dt_Customer)
data['First_day'] = '01-01-2015'
data['First_day'] = pd.to_datetime(data.First_day)
data['Day_engaged'] = (data['First_day'] - data['Dt_Customer']).dt.days

# %%
data['Age'] = (pd.Timestamp('now').year) - (pd.to_datetime(data['Dt_Customer']).dt.year)
print("Unique categories present in the Age:\n",data['Age'].value_counts())
data['Age'].value_counts().plot(kind='bar',color = 'seagreen',edgecolor = "black",linewidth = 3)
plt.title("Frequency Of Each Category in the Age Variable \n")
# Out:
# Unique categories present in the Age:
#  8    1173
# 7     553
# 9     490
# Name: Age, dtype: int64
# Text(0.5, 1.0, 'Frequency Of Each Category in the Age Variable \n')

# %%
data.head()
# Out:
#    Year_Birth   Education Marital_Status  ...  First_day Day_engaged  Age
# 0        1957  Graduation         Single  ... 2015-01-01         997    9
# 1        1954  Graduation         Single  ... 2015-01-01         151    7
# 2        1965  Graduation   Relationship  ... 2015-01-01         498    8
# 3        1984  Graduation   Relationship  ... 2015-01-01          91    7
# 4        1981         PhD   Relationship  ... 2015-01-01         347    7
#
# [5 rows x 16 columns]

# %%
data=data.drop(columns=["Dt_Customer", "First_day", "Year_Birth", "Dt_Customer", "Recency", "Complain","Response"],axis=1)
data.head()
# Out:
#     Education Marital_Status   Income  ...  TotalAcceptedCmp  Day_engaged  Age
# 0  Graduation         Single  58138.0  ...                 0          997    9
# 1  Graduation         Single  46344.0  ...                 0          151    7
# 2  Graduation   Relationship  71613.0  ...                 0          498    8
# 3  Graduation   Relationship  26646.0  ...                 0           91    7
# 4         PhD   Relationship  58293.0  ...                 0          347    7
#
# [5 rows x 10 columns]

# %%
import plotly.express as px
plt.figure(figsize=(28, 6))
px.area(data, x="Expenditure", y="Education")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5007075d-cf5f-44ed-94b5-3432f63c1487" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5007075d-cf5f-44ed-94b5-3432f63c1487")) {
#                     Plotly.newPlot(
#                         '5007075d-cf5f-44ed-94b5-3432f63c1487',
# ...

# %%
px.area(data, x="Expenditure", y="Marital_Status")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="40de0a33-6271-4d0c-967b-e48fd8ffbc3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("40de0a33-6271-4d0c-967b-e48fd8ffbc3b")) {
#                     Plotly.newPlot(
#                         '40de0a33-6271-4d0c-967b-e48fd8ffbc3b',
# ...

# %%
import plotly.express as px
plt.figure(figsize=(28, 6))
px.density_heatmap(data, x="Expenditure", y="Age")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4661ccc1-0a60-4a10-b6b5-b21e6a26e6e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4661ccc1-0a60-4a10-b6b5-b21e6a26e6e8")) {
#                     Plotly.newPlot(
#                         '4661ccc1-0a60-4a10-b6b5-b21e6a26e6e8',
# ...

# %%
plt.figure(figsize=(28, 6))
px.density_heatmap(data,x="Expenditure", y="NumTotalPurchases")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="591bd05c-f203-4274-bed9-79b009764694" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("591bd05c-f203-4274-bed9-79b009764694")) {
#                     Plotly.newPlot(
#                         '591bd05c-f203-4274-bed9-79b009764694',
# ...

# %%
plt.figure(figsize=(28, 6))
px.area(data,x="Expenditure", y="Day_engaged")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bff96a20-bee8-4632-bd1e-d788e570f3b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bff96a20-bee8-4632-bd1e-d788e570f3b2")) {
#                     Plotly.newPlot(
#                         'bff96a20-bee8-4632-bd1e-d788e570f3b2',
# ...
